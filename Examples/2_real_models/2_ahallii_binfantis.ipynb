# %% [markdown]
# # Simulating Superfluous Crossfeeding
# The toy model community, displayed below, simulates bacteria in co-culture feeding on seperate media metabolites. An additional metabolite is provided in the media, but only organism 1 is able to metabolize this nutrient into a consumable metabolite for organism 2.
#
# This interaction is superfluous as it provides no direct benefit (biomass growth) to organism 1, but mathematically will be optimized to maximize total community growth.
#
# ![Superfluous Crossfeeding Microbes](../../figures/toy_model_figs/network_diagrams/4_2_superfluous_crossfeed_diagram.svg)
#
# The following notebook will simulate co-culture of this toy model community, using:
# - giFBA
# - FBA
# - MICOM
# - compartmentalized FBA
#
# Followed by comparison of all methods

# %%
import gifba
import cobra as cb
from micom import Community
import matplotlib.pyplot as plt
from cobra import Model
import pandas as pd
import numpy as np
import optlang

# %% [markdown]
# ## Greedy Interaction FBA

# %%
# AGORA models
AH_path = "data/Eubacterium_hallii_DSM_3353.mat"
BI_path = "data/Bifidobacterium_longum_infantis_ATCC_15697.mat"

AH = cb.io.load_matlab_model(AH_path)
BI = cb.io.load_matlab_model(BI_path)

models = [BI, AH]
ids_list = ["BI", "AH"]
rel_abund = [0.5, 0.5]

media = {
	'EX_o2(e)': 0, #aerobic/anaerobic
	'EX_h2o(e)': -1000,
	'EX_pi(e)': -1000,
	'EX_fe2(e)': -1000,
	'EX_fe3(e)': -1000,
	'EX_zn2(e)': -1000,
	'EX_so4(e)': -1000,
	'EX_cu2(e)': -1000,
	'EX_k(e)': -1000,
	'EX_mg2(e)': -1000,
	'EX_mn2(e)': -1000,
	'EX_cd2(e)': -1000,
	'EX_cl(e)': -1000,
	'EX_ca2(e)': -1000,
	'EX_cobalt2(e)': -1000,
	'EX_glc_D(e)': -10,
	'EX_nh4(e)': -20,

	'EX_ribflv(e)': -1000,
	'EX_pnto_R(e)': -1000,
	'EX_nac(e)': -1000,
	'EX_his_L(e)': -1000,
	'EX_asn_L(e)': -1000,
	'EX_glycys(e)': -1000,

	'EX_lys_L(e)': -1000,
	'EX_ala_L(e)': -1000,
	'EX_met_L(e)': -1000,
	'EX_leu_L(e)': -1000,
	'EX_hxan(e)': -1000,    
    'EX_glyglu(e)': -1000,
	'EX_ser_L(e)': -1 #-1
}
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2773321
# Academic license - for non-commercial use only - expires 2027-02-01
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e

# %%
# initialize community
community = gifba.gifbaObject(models, 
                              media,
                              rel_abund=rel_abund) 

# run iterations
media_flux, org_flux = community.run_gifba(iters=5, 
                                           method="pfba", 
                                           v=True)

# view results and prep network files for cytoscape
summary = community.summarize() 
edges, nodes = summary.to_cytoscape()

# only visualize substantial edges keeping biomass fluxes
edges = edges[(abs(edges["Value"]) > 0.1) | (edges["Target"] == "biomass[c]")] 
nodes = nodes[nodes["ID"].isin(edges[["Source", "Target"]].values.flatten())] 

# store
edges.to_csv("../figures/real_model_figs/cytoscape_networks/AH_BI_edges.csv", index=False)
nodes.to_csv("../figures/real_model_figs/cytoscape_networks/AH_BI_nodes.csv", index=False)
# Out:
# Read LP format model from file /tmp/tmpvh3nog9b.lp
# Reading time = 0.00 seconds
# : 932 rows, 2064 columns, 8440 nonzeros
# Read LP format model from file /tmp/tmpl3j1zjp3.lp
# Reading time = 0.00 seconds
# : 980 rows, 2102 columns, 8980 nonzeros
#
# Iteration: 0
# EX_glc_D(e) over-consumed by factor of 2.000000000000 (rerun count: 0)
#
# Iteration: 1
# EX_glc_D(e) over-consumed by factor of 2.000000000001 (rerun count: 0)
#
# Iteration: 2
# EX_glc_D(e) over-consumed by factor of 2.000000000000 (rerun count: 0)
#
# Iteration: 3
# EX_glc_D(e) over-consumed by factor of 2.000000000000 (rerun count: 0)
#
# Iteration: 4
# EX_glc_D(e) over-consumed by factor of 2.000000000000 (rerun count: 0)
# Model did not converge or show periodicity within the iteration limit, results may be unreliable.
# 4 iterations (90.0%) will be used for flux calculations, but consider increasing the number of iterations or checking model setup.

# %% [markdown]
# ## Simple FBA
# Use COBRApy to simulate individual microbes' growth capability

# %%
# # run simulation to compare with COBRApy FBA
with models[0] as mdl:
    for ex, flux in media.items():
        if ex in mdl.exchanges:
            mdl.exchanges.get_by_id(ex).lower_bound = flux
    bio1_fba = mdl.optimize().objective_value

with models[1] as mdl:
    for ex, flux in media.items():
        if ex in mdl.exchanges:
            mdl.exchanges.get_by_id(ex).lower_bound = flux
    bio2_fba = mdl.optimize().objective_value

# %% [markdown]
# ## Compartmentalized FBA
#
# ### Finding the cFBA Pareto-Optimal Points
# Since cFBA relies on the Multi-Objective Optimization, the following code is used to identify/estimate the Pareto Frontier. This is done via the following procedure:
# 1) Maximize Total Biomass
# 2) Constrain total biomass to maximum
# 3) Maximize Organism 1 biomass growth
# 4) Minimize Organism 1 biomass growth
# 5) Create Set of n-points ranging from Min to Max
# 6) Constrain organism 1 growth to one value in set (Step 5)
# 7) Maximize Organism 1 biomass growth
# 8) Minimize Organism 1 biomass growth
# 9) Repeat 6-8 for all points in set (Step 5)

# %%
cfba_model, micom_comm, objective_dict = gifba.utils.prep_micom_cfba("compartmentalized_model", ["AH", "BI"], [AH_path, BI_path], rel_abund=rel_abund)

# reset all exchanges
for exchange in cfba_model.exchanges:
    cfba_model.reactions.get_by_id(exchange.id).upper_bound = 1000
    cfba_model.reactions.get_by_id(exchange.id).lower_bound = -1000 if len(exchange.metabolites) > 1 else 0

# set media bounds
media_tmp = {rxn_id.replace("(e)", "_m"): flux for rxn_id, flux in media.items()}
for rxn in cfba_model.reactions:
    if rxn.id in media_tmp:
        # print(f"Setting bounds for {rxn.id}: {media_tmp[rxn.id]}")
        cfba_model.reactions.get_by_id(rxn.id).lower_bound = media_tmp[rxn.id]

#  Optimize compartmentalized model for (optimal) community growth 
solution = cfba_model.optimize()
print(f"{cfba_model.id}, Objective value: {solution.objective_value}")
print(f"Objective Expression: {cfba_model.objective.expression}")


#  Set community growth constraint
comm_growth = solution.objective_value
community_expr = sum([coeff * cfba_model.reactions.get_by_id(rxn.id).flux_expression for rxn, coeff in objective_dict.items()])
# COMMENT OUT IF RE-RUNNING OR RESTART KERNEL
constraint = optlang.Constraint(
    community_expr,
    lb=comm_growth-1e-6,  # lower bound
    ub=comm_growth+1e-6,  # upper bound
    name="community_growth_constraint"
    )
cfba_model.solver.add(constraint)


# Get Min/Max Flux for organism 1
first_obj_key = next((k for k in objective_dict.keys() if getattr(k, "id", str(k)).endswith(f"_{ids_list[0]}")),
                        list(objective_dict.keys())[0])
second_obj_key = next((k for k in objective_dict.keys() if getattr(k, "id", str(k)).endswith(f"_{ids_list[1]}")),
                        list(objective_dict.keys())[1])
# minimize flux of first organism
cfba_model.objective = cfba_model.reactions.get_by_id(first_obj_key.id)
cfba_model.objective.direction = 'min'
solution_min_s1 = cfba_model.optimize()

# maximize flux of first organism
cfba_model.objective.direction = 'max'
solution_max_s1 = cfba_model.optimize()

# store results
cfba_results = pd.DataFrame(columns=["First_Org_Flux", "Second_Org_Max_Flux", "Second_Org_Min_Flux"])


# Vary first organism flux between min and max and get second organism min/max
for val in np.linspace(solution_min_s1.objective_value, solution_max_s1.objective_value, 101):
    # update constraint on first organism
    cfba_model.reactions.get_by_id(first_obj_key.id).upper_bound = rel_abund[0]*val
    cfba_model.reactions.get_by_id(first_obj_key.id).lower_bound = rel_abund[0]*val

    # optimize for second organism
    cfba_model.objective = cfba_model.reactions.get_by_id(second_obj_key.id)
    # minimize then maximize org 2
    cfba_model.objective.direction = 'min'
    solution_min_s2 = cfba_model.optimize()
    cfba_model.objective.direction = 'max'
    solution_max_s2 = cfba_model.optimize()


    # store results
    cfba_results.loc[len(cfba_results)] = {
        "First_Org_Flux": rel_abund[0]*val,
        "Second_Org_Max_Flux": rel_abund[1]* solution_max_s2.objective_value,
        "Second_Org_Min_Flux": rel_abund[1]*solution_min_s2.objective_value,
    }
# Out:
# Output()
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# compartmentalized_model, Objective value: 0.4272023561754505
# Objective Expression: 0.5*biomass525__BI - 0.5*biomass525__BI_reverse_aa57e + 0.5*biomass536__AH - 0.5*biomass536__AH_reverse_45c34

# %% [markdown]
# ## MICOM
# Simulating Community Growth with the MICOM package. A range of tradeoff values are chosen to demonstrate how simulation is affected.

# %%
# run with micom
micom_results = pd.DataFrame(columns=["tradeoff", "Org1_growth", "Org2_growth"])

abund = community.rel_abund.flatten()

# create community dataframe (built above with gifba.utils.prep_micom_cfba())
micom_comm = pd.DataFrame({ 
    "id": ["Org1", "Org2"],
    "file": [BI_path,AH_path],
    "abundance": abund
})




# # create micom community
micom_comm = Community(micom_comm)
micom_comm.medium = {ex: abs(flux) for ex, flux in media_tmp.items()}
print(f"Micom medium: {micom_comm.medium}")
micom_comm.solver = "gurobi"

# check exchange names and fmedia names
for ex in micom_comm.exchanges:
    print(f"Exchange: {ex.id}, Lower bound: {ex.lower_bound}, Upper bound: {ex.upper_bound}")

solutions = micom_comm.cooperative_tradeoff(fraction=np.linspace(1, 0, 101), pfba=True)
for idx, sol in enumerate(solutions["solution"]):
    print(f"Solution alpha: {solutions['tradeoff'][idx]}", end="  ")
    # print(sol.members)
    org_growth = (sol.members["abundance"] * sol.members["growth_rate"]).to_numpy()[0:-1]
    print(org_growth)
    micom_results.loc[len(micom_results)] = [solutions['tradeoff'][idx], org_growth[0], org_growth[1]]
# Out:
# Output()
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e
# No defined compartments in model model. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Micom medium: {'EX_asn_L_m': 1000, 'EX_ca2_m': 1000, 'EX_cd2_m': 1000, 'EX_cl_m': 1000, 'EX_cobalt2_m': 1000, 'EX_cu2_m': 1000, 'EX_fe2_m': 1000, 'EX_fe3_m': 1000, 'EX_glc_D_m': 10, 'EX_glycys_m': 1000, 'EX_glyglu_m': 1000, 'EX_h2o_m': 1000, 'EX_his_L_m': 1000, 'EX_hxan_m': 1000, 'EX_k_m': 1000, 'EX_leu_L_m': 1000, 'EX_met_L_m': 1000, 'EX_mg2_m': 1000, 'EX_mn2_m': 1000, 'EX_nac_m': 1000, 'EX_nh4_m': 20, 'EX_pi_m': 1000, 'EX_pnto_R_m': 1000, 'EX_ribflv_m': 1000, 'EX_so4_m': 1000, 'EX_zn2_m': 1000, 'EX_ala_L_m': 1000, 'EX_lys_L_m': 1000, 'EX_ser_L_m': 1}
# Exchange: EX_12ppd_S_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_4abut_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_4abz_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_4ahmmp_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_5mthf_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_C02528_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_HC02191_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_HC02192_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_HC02193_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_M01989_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_M03134_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_Ser_Thr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_T_antigen_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_Tn_antigen_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_ac_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_acald_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_acgal_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_acgam_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_acnam_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_adocbl_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_alaasp_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_alagln_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_alaglu_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_alagly_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_alahis_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_alaleu_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_alathr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_arab_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_arabinogal_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_arabttr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_arbt_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_asn_L_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_btn_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_butam_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_ca2_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_cbl1_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_cd2_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_cgly_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_cholate_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_cl_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_co2_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_cobalt2_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_core2_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_core3_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_core4_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_core5_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_core6_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_core7_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_core8_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_cu2_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_dchac_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_dextrin_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_dgchol_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_dhna_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_dma_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_dsT_antigen_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_etoh_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_f1a_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_fe2_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_fe3_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_fol_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_for_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_fru_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_fuc_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_fum_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_gal_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_galam_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_gchola_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glc_D_m, Lower bound: -10, Upper bound: 1000.0
# Exchange: EX_glcur_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_gly_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glyasn_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glyasp_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glyc_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glyc3p_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glycys_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_glygln_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glyglu_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_glyleu_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glymet_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glyphe_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glypro_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glytyr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_gncore1_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_gncore2_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_h_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_h2o_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_hg2_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_his_L_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_hxan_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_ile_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_inulin_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_isomal_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_k_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_kesto_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_kestopt_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_kestottr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_lac_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_lactl_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_lcts_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_leu_L_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_malt_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_malthx_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_malttr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_man_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_mantr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_melib_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_met_D_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_met_L_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_metala_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_metsox_S_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_mg2_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_mn2_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_mnl_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_mqn7_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_mqn8_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_na1_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_nac_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_nh4_m, Lower bound: -20, Upper bound: 1000.0
# Exchange: EX_ni2_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_norval_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_o2_m, Lower bound: 0, Upper bound: 1000.0
# Exchange: EX_oxa_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_pb_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_peamn_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_phe_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_pi_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_pnto_R_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_ppi_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_pro_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_pydam_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_pydx_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_pydxn_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_r406_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_r788_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_raffin_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_rib_D_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_ribflv_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_rmn_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_sT_antigen_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_sTn_antigen_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_salcn_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_so4_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_stys_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_succ_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_sucr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_taur_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_tchola_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_tdchola_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_tdechola_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_thf_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_thm_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_tre_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_trp_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_tyr_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_ura_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_urea_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_val_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_xan_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_xyl_D_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_xylottr_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_zn2_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_12dhchol_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_7a_czp_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_ala_L_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_anzp_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_but_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_chlphncl_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_cro4_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_czp_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_drib_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_gln_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_glu_L_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_h2_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_lac_D_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_lys_L_m, Lower bound: -1000, Upper bound: 1000.0
# Exchange: EX_mobd_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_nchlphncl_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_nmn_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_nzp_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_pcresol_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_ppa_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_ptrc_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_rbflvrd_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_sbt_D_m, Lower bound: -0.0, Upper bound: 1000.0
# Exchange: EX_ser_L_m, Lower bound: -1, Upper bound: 1000.0
# Exchange: EX_spmd_m, Lower bound: -0.0, Upper bound: 1000.0
# Solution alpha: 1.0  [1.04059689e-16 4.27202356e-01]
# Solution alpha: 0.99  [0.01179544 0.41113489]
# Solution alpha: 0.98  [0.02341373 0.39524458]
# Solution alpha: 0.97  [0.03512059 0.3792657 ]
# Solution alpha: 0.96  [0.04682745 0.36328681]
# Solution alpha: 0.95  [0.05628437 0.34955787]
# Solution alpha: 0.94  [0.0609911  0.34057911]
# Solution alpha: 0.9299999999999999  [0.06569783 0.33160036]
# Solution alpha: 0.92  [0.07040456 0.32262161]
# Solution alpha: 0.91  [0.07511129 0.31364286]
# Solution alpha: 0.9  [0.07981802 0.30466411]
# Solution alpha: 0.89  [0.08452474 0.29568535]
# Solution alpha: 0.88  [0.08923147 0.2867066 ]
# Solution alpha: 0.87  [0.0939382  0.27772785]
# Solution alpha: 0.86  [0.09864493 0.2687491 ]
# Solution alpha: 0.85  [0.10335166 0.25977035]
# Solution alpha: 0.84  [0.10805839 0.25079159]
# Solution alpha: 0.83  [0.11276511 0.24181284]
# Solution alpha: 0.8200000000000001  [0.11747184 0.23283409]
# Solution alpha: 0.81  [0.12147079 0.22456312]
# Solution alpha: 0.8  [0.1244794  0.21728249]
# Solution alpha: 0.79  [0.12658776 0.21090211]
# Solution alpha: 0.78  [0.12786134 0.2053565 ]
# Solution alpha: 0.77  [0.12913492 0.19981089]
# Solution alpha: 0.76  [0.13040851 0.19426528]
# Solution alpha: 0.75  [0.13168209 0.18871968]
# Solution alpha: 0.74  [0.13295568 0.18317407]
# Solution alpha: 0.73  [0.13405055 0.17780717]
# Solution alpha: 0.72  [0.13405055 0.17353514]
# Solution alpha: 0.71  [0.13405055 0.16926312]
# Solution alpha: 0.7  [0.13405055 0.1649911 ]
# Solution alpha: 0.69  [0.13405055 0.16071907]
# Solution alpha: 0.6799999999999999  [0.13405055 0.15644705]
# Solution alpha: 0.6699999999999999  [0.13405055 0.15217503]
# Solution alpha: 0.6599999999999999  [0.13405055 0.147903  ]
# Solution alpha: 0.6499999999999999  [0.13405055 0.14363098]
# Solution alpha: 0.64  [0.13405055 0.13935896]
# Solution alpha: 0.63  [0.13405055 0.13508694]
# Solution alpha: 0.62  [0.13243273 0.13243274]
# Solution alpha: 0.61  [0.13029672 0.13029672]
# Solution alpha: 0.6  [0.12816071 0.12816071]
# Solution alpha: 0.59  [0.12602469 0.1260247 ]
# Solution alpha: 0.5800000000000001  [0.12388868 0.12388868]
# Solution alpha: 0.5700000000000001  [0.12175267 0.12175267]
# Solution alpha: 0.56  [0.11961666 0.11961666]
# Solution alpha: 0.55  [0.11748065 0.11748065]
# Solution alpha: 0.54  [0.11534464 0.11534464]
# Solution alpha: 0.53  [0.11320862 0.11320862]
# Solution alpha: 0.52  [0.11107261 0.11107261]
# Solution alpha: 0.51  [0.1089366 0.1089366]
# Solution alpha: 0.5  [0.10680059 0.10680059]
# Solution alpha: 0.49  [0.10466458 0.10466458]
# Solution alpha: 0.48  [0.10252857 0.10252857]
# Solution alpha: 0.47  [0.10039255 0.10039255]
# Solution alpha: 0.45999999999999996  [0.09825654 0.09825654]
# Solution alpha: 0.44999999999999996  [0.09612053 0.09612053]
# Solution alpha: 0.43999999999999995  [0.09398452 0.09398452]
# Solution alpha: 0.42999999999999994  [0.09184851 0.09184851]
# Solution alpha: 0.42000000000000004  [0.08971249 0.08971249]
# Solution alpha: 0.41000000000000003  [0.08757648 0.08757648]
# Solution alpha: 0.4  [0.08544047 0.08544047]
# Solution alpha: 0.39  [0.08330446 0.08330446]
# Solution alpha: 0.38  [0.08116845 0.08116845]
# Solution alpha: 0.37  [0.07903244 0.07903244]
# Solution alpha: 0.36  [0.07689642 0.07689642]
# Solution alpha: 0.35  [0.07476041 0.07476041]
# Solution alpha: 0.33999999999999997  [0.0726244 0.0726244]
# Solution alpha: 0.32999999999999996  [0.07048839 0.07048839]
# Solution alpha: 0.31999999999999995  [0.06835238 0.06835238]
# Solution alpha: 0.30999999999999994  [0.06621637 0.06621637]
# Solution alpha: 0.29999999999999993  [0.06408035 0.06408035]
# Solution alpha: 0.29000000000000004  [0.06194434 0.06194434]
# Solution alpha: 0.28  [0.05980833 0.05980833]
# Solution alpha: 0.27  [0.05767232 0.05767232]
# Solution alpha: 0.26  [0.05553631 0.05553631]
# Solution alpha: 0.25  [0.05340029 0.05340029]
# Solution alpha: 0.24  [0.05126428 0.05126428]
# Solution alpha: 0.22999999999999998  [0.04912827 0.04912827]
# Solution alpha: 0.21999999999999997  [0.04699226 0.04699226]
# Solution alpha: 0.20999999999999996  [0.04485625 0.04485625]
# Solution alpha: 0.19999999999999996  [0.04272024 0.04272024]
# Solution alpha: 0.18999999999999995  [0.04058422 0.04058422]
# Solution alpha: 0.17999999999999994  [0.03844821 0.03844821]
# Solution alpha: 0.16999999999999993  [0.0363122 0.0363122]
# Solution alpha: 0.16000000000000003  [0.03417619 0.03417619]
# Solution alpha: 0.15000000000000002  [0.03204018 0.03204018]
# Solution alpha: 0.14  [0.02990416 0.02990417]
# Solution alpha: 0.13  [0.02776815 0.02776815]
# Solution alpha: 0.12  [0.02563214 0.02563214]
# Solution alpha: 0.10999999999999999  [0.02349613 0.02349613]
# Solution alpha: 0.09999999999999998  [0.02136012 0.02136012]
# Solution alpha: 0.08999999999999997  [0.01922411 0.01922411]
# Solution alpha: 0.07999999999999996  [0.01708809 0.01708809]
# Solution alpha: 0.06999999999999995  [0.01495208 0.01495208]
# Solution alpha: 0.05999999999999994  [0.01281607 0.01281607]
# Solution alpha: 0.04999999999999993  [0.01068006 0.01068006]
# Solution alpha: 0.040000000000000036  [0.00854405 0.00854405]
# Solution alpha: 0.030000000000000027  [0.00640804 0.00640804]
# Solution alpha: 0.020000000000000018  [0.00427202 0.00427202]
# Solution alpha: 0.010000000000000009  [0.00213601 0.00213601]
# Solution alpha: 0.0  [4.59663129e-06 6.99083959e-06]

# %% [markdown]
# # Comparison
# Each simulation technique is simulated via plotting expected growth. Organism 1 is plotted on the x-axis and Organism 2 on the y-axis.
#
# Each color represents a simulation method.
#
# giFBA is the only iterative method, so all iterates are shown. Circles get smaller as the simulation converges to the final iteration.

# %%
#plot model results

# sizes for markers
fba_marker_size, cfba_marker_size, micom_marker_size = 100, 20, 50
gifba_marker_sizes = np.linspace(18, 4, community.iters)**2 * np.pi
micom_line_width = 0.5
colors = ["b", "r", "g", "orange", "purple"] # gifba, FBA, cFBA, MICOM


# plot giFBA results
bio1_gifba = community.org_fluxes.loc[0, :]["EX_biomass(e)"]
bio2_gifba = community.org_fluxes.loc[1, :]["EX_biomass(e)"]
plt.scatter(bio1_gifba, bio2_gifba, 
            color=colors[0],
            marker="o", 
            s=gifba_marker_sizes, 
            alpha=0.25,
            label="giFBA Result",
            zorder = 2)

# compared to cobrapy FBA
plt.scatter(bio1_fba, bio2_fba, 
            color=colors[1], 
            marker="P", 
            s=fba_marker_size,
            label='FBA Result',
            zorder=3)


# compared to cFBA
plt.plot(cfba_results["First_Org_Flux"], cfba_results["Second_Org_Max_Flux"],
            color=colors[2], 
            marker="x",
            ms=cfba_marker_size,
            lw=0,
            label='cFBA Sol. Space',
            zorder=3)

# import plotting helper module
import sys
import os
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
import plotting_module as pm
        
# compared to MICOM (both interpretations)
pm.plot_micom_tradeoff_pts(micom_results, 
                           "relative", 
                           [0.0, 0.5, 1.0], # alpha tradeoffs to add text labels to
                           community.rel_abund, 
                           colors[3], 
                           micom_marker_size, 
                           micom_line_width, 
                           [(0, 0), (-0, 0), (0, 0)]) # x, y offsets for text labels

# create custom legend entry
micom_rel_handle = plt.Line2D([0], [0], color=colors[3], lw=micom_line_width, marker="d", label='MICOM Results (Rel. Rates)')
handles, labels = plt.gca().get_legend_handles_labels() # pull original legend
handles.append(micom_rel_handle) # add new legend entry
labels.append("MICOM Results") # add new legend entry
plt.legend(handles=handles, labels=labels,
           fontsize=11, loc='center right', bbox_to_anchor=(1.4, 0.5), ncol=1, frameon=False, labelspacing=1.5) 

# annotate
axis_lab_size = 14
plt.grid(zorder=0, alpha=0.5)
plt.xlabel(r"BI Biomass Flux ($\frac{g_1}{g_T \cdot hr}$)", fontsize=axis_lab_size)
plt.ylabel(r"AH Biomass Flux ($\frac{g_2}{g_T \cdot hr}$)", fontsize=axis_lab_size)
plt.xlim(-0.05, 0.5)
plt.ylim(-0.05, 0.5)

plt.savefig("../figures/real_model_figs/paper_figs/2_ahallii_binfantis.svg", bbox_inches='tight')
